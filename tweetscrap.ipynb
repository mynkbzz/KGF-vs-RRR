# %% [markdown]
# <a href="https://colab.research.google.com/github/mynkbzz/KGF-vs-RRR/blob/main/tweetscrap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q snscrape==0.3.4

# %%
import os
import pandas as pd
from datetime import date

# %%
search_term = 'rrr'
from_date = '2022-04-14'
end_date = '2022-04-16'

# %%
os.system(f"snscrape --since {from_date} twitter-search '{search_term} until:{end_date}' > result-tweets.txt")
if os.stat("result-tweets.txt").st_size == 0:
  counter = 0
else:
  df = pd.read_csv('result-tweets.txt', names=['link'])
  counter = df.size

print('Number Of Tweets : '+ str(counter))
# Out:
# Number Of Tweets : 23589

# %%
max_results = 22000

# %%
extracted_tweets = "snscrape --format '{content!r}'"+ f" --max-results {max_results} --since {from_date} twitter-search '{search_term} until:{end_date}' > extracted-tweets.txt"
os.system(extracted_tweets)
if os.stat("extracted-tweets.txt").st_size == 0:
  print('No Tweets found')
else:
  df = pd.read_csv('extracted-tweets.txt', names=['content'])
  for row in df['content'].iteritems():
    print(row)
# Out:
# Streaming output truncated to the last 5000 lines.
# (16354, "'@samrudh_david RRR first day collections ni cross chestada bro??'")
# (16355, "'@_rrr_oo92 吹けます！口で'")
# (16356, "'@RRRMovie @TrendsRamCharan @Alokkhosla143 🔥🔥🔥 king 👑 https://t.co/SVJc3DAuPt'")
# (16357, "'komuram bheem song emina puttintiki ra Chelli lanti song aa ra")
# (16358, "'@rrr___uuupn ナイスです！！決勝もファイトです！！'")
# (16359, "'@rrr_6_nnn あざは大丈夫ですか？？？\\n\\n🏍💨楽しいですね😉\\n\\nお互い🏍ライフ楽しみましょう👍'")
# (16360, "'@Rrr_rrr_e 아니아니 진짜 귀여운데? 💖😊 최고사랑'")
# (16361, "'@Alokkhosla143 @AlwaysRamCharan @RRRMovie @TrendsRamCharan @RamcharanTeam @TeamRC_KDP @megastar_fanz @Chiru_FC @Team_RC_kDKR @Ustaad07 🙏❤️'")
# (16362, "'@Alokkhosla143 @AlwaysRamCharan @RRRMovie @TrendsRamCharan @RamcharanTeam @TeamRC_KDP @megastar_fanz @Chiru_FC @Team_RC_kDKR @Ustaad07 Att'")
# (16363, "'@RRRMovie @TrendsRamCharan @Alokkhosla143 Jai Charan 🔥🔥'")
# (16364, "'@373_rrr_ きゅんきゅんした\\nあいしてるよみなみ！！！！'")
# ...
